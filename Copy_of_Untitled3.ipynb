# %% [markdown]
# <a href="https://colab.research.google.com/github/wanxttt/SAB_Squad/blob/main/Copy_of_Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Upgrade pip, setuptools, and wheel first
# !pip install --upgrade pip setuptools wheel
# Then install roboflow
# !pip install roboflow

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="NR7RVf0O2h00hGGwrcvE")
project = rf.workspace("avanthika-s-nfpex").project("indian-emergency-vehicles")
version = project.version(3)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# !pip install ultralytics

# %%
# Cell 3: Train YOLOv11
from ultralytics import YOLO

# Load a pretrained YOLOv11 nano model (lightweight for Colab; use 'yolov11s.pt' or 'yolov11m.pt' for larger if you have GPU)
model = YOLO('yolov8n.pt')

# Train on the downloaded dataset (adjust epochs, batch, etc., based on your needs/hardware)
results = model.train(
    data="/content/Indian-emergency-vehicles-3/data.yaml",  # Path to the dataset config file
    epochs=50,  # Start with 50; increase for better accuracy
    imgsz=640,  # Image size
    batch=16,  # Adjust based on GPU memory (e.g., 8 if low RAM)
    name='emergency_vehicle_detection' ,
    patience = 20# Output folder name
)

# Cell 4: (Optional) Validate the trained model
metrics = model.val()
print(metrics)

# Cell 5: (Optional) Export the model for deployment (e.g., ONNX format)
model.export(format='onnx')
# Out:
# Ultralytics 8.4.7 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %% [markdown]
# # Task
# Install required system dependencies for `pillow-avif-plugin` and then install `roboflow`.

# %% [markdown]
# ## install_system_deps_and_roboflow
#
# ### Subtask:
# Install required system dependencies for `pillow-avif-plugin` and then install `roboflow`.

# %% [markdown]
# **Reasoning**:
# The previous attempt to install `roboflow` failed because `pillow-avif-plugin` could not be built due to missing system dependencies. Installing `libavif-dev` via `apt-get` is required to resolve this issue as per the instructions.

# %%
import sys
# Install libavif-dev for pillow-avif-plugin support
# !apt-get update -qq && apt-get install -y libavif-dev

# Re-install roboflow to ensure all dependencies are built correctly
# !pip install roboflow
print("System dependencies and roboflow installed.")

# %% [markdown]
# ## initialize_roboflow_and_download_dataset
#
# ### Subtask:
# Re-run the Roboflow initialization and dataset download after successful installation.

# %% [markdown]
# **Reasoning**:
# The previous attempt to import Roboflow failed due to a ModuleNotFoundError. After successfully installing the necessary system dependencies and Roboflow in the prior step, it's now appropriate to re-execute the code that initializes Roboflow and downloads the dataset.

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="NR7RVf0O2h00hGGwrcvE")
project = rf.workspace("avanthika-s-nfpex").project("indian-emergency-vehicles")
version = project.version(3)
dataset = version.download("yolov8")

# %% [markdown]
# **Reasoning**:
# The previous step successfully downloaded and extracted the dataset. The next logical step in the notebook is to install `ultralytics`, which is required for the subsequent model training cell.

# %%
# !pip install ultralytics

# %% [markdown]
# **Reasoning**:
# The `ultralytics` library has been successfully installed, and the dataset has been downloaded. The next step is to train the YOLO model using the downloaded dataset, validate it, and export it for potential deployment.

# %%
from ultralytics import YOLO

# Load a pretrained YOLOv11 nano model (lightweight for Colab; use 'yolov11s.pt' or 'yolov11m.pt' for larger if you have GPU)
model = YOLO('yolov8n.pt')

# Train on the downloaded dataset (adjust epochs, batch, etc., based on your needs/hardware)
results = model.train(
    data="/content/Indian-emergency-vehicles-3/data.yaml",  # Path to the dataset config file
    epochs=50,  # Start with 50; increase for better accuracy
    imgsz=640,  # Image size
    batch=16,  # Adjust based on GPU memory (e.g., 8 if low RAM)
    name='emergency_vehicle_detection' ,
    patience = 20# Output folder name
)

# Cell 4: (Optional) Validate the trained model
metrics = model.val()
print(metrics)

# Cell 5: (Optional) Export the model for deployment (e.g., ONNX format)
model.export(format='onnx')
